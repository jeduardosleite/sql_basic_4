# %% [markdown]
# <a href="https://colab.research.google.com/github/jeduardosleite/sql_basic_4/blob/main/sql_mod4_exercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f177e0f5-a810-48fa-8c7b-cfbd113ea57a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f177e0f5-a810-48fa-8c7b-cfbd113ea57a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
query_1 = pd.read_csv('query1.csv')
query_2 = pd.read_csv('query2.csv')
query_3 = pd.read_csv('query3.csv')
query_4 = pd.read_csv('query4.csv')
query_5 = pd.read_csv('query5.csv')
query_6 = pd.read_csv('query6.csv')
query_7 = pd.read_csv('query7.csv')
query_total = pd.read_csv('query_total.csv')

# %% [markdown]
# # Module 21 - Introduction SQL
#
# ## Lesson 4
#
# Now i'll use concepts of:
# - Selecting datas with ***AND***, ***OR***, ***IN*** and ***BETWEEN***
# - Filter ***LIKE*** and ***WILDCARDS***
# - Condition selection with ***CASE***, ***WHEN***, ***THEN***
#
# ----
# But, firstly we need create a bucket in AWS S3 and make a table (*query_total*)
# ```sql
# CREATE TABLE EXTERNAL transacoes(
#   id_cliente BIGINT,
#   id_transacao BIGINT,
#   valor FLOAT,
#   id_loja STRING
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
# WITH SERDEPROPERTIES (
#   'separatorChar' = ',',
#   'quoteChar' = '"',
#   'escapeChar' = '\\'
# )
# STORED AS TEXTFILE
# LOCATION 's3://mod3-jeduardo/';
# ```

# %%
query_total
# Out:
#    id_cliente  id_transacao    valor      id_loja
# 0           1     768805383    50.74       magalu
# 1           2     768805399    30.90     giraffas
# 2           3     818770008   110.00   postoshell
# 3           1      76856563  2000.90       magalu
# 4           1     767573759    15.70       subway
# 5           3     818575758     2.99  seveneleven
# 6           4     764545534    50.74        extra
# 7           5      76766789    10.00       subway
# 8           3    8154567758  1100.00       shopee

# %% [markdown]
# ## SELECTING DATAS
#
# ### Query 1
#
# ```sql
# SELECT *
# FROM transacoes
# WHERE valor > 30 AND id_loja = 'magalu';
# ```

# %%
query_1
# Out:
#    id_cliente  id_transacao    valor id_loja
# 0           1     768805383    50.74  magalu
# 1           1      76856563  2000.90  magalu

# %% [markdown]
# ### Query 2
#
# ```sql
# SELECT *
# FROM transacoes
# WHERE valor > 10 OR id_loja = 'magalu';
# ```

# %%
query_2
# Out:
#    id_cliente  id_transacao    valor     id_loja
# 0           1     768805383    50.74      magalu
# 1           2     768805399    30.90    giraffas
# 2           3     818770008   110.00  postoshell
# 3           1      76856563  2000.90      magalu
# 4           4     764545534    50.74       extra
# 5           3    8154567758  1100.00      shopee

# %% [markdown]
# ### Query 3
#
# ```sql
# SELECT *
# FROM transacoes
# WHERE id_loja IN ('magalu','subway') AND valor > 10;
# ```

# %%
query_3
# Out:
#    id_cliente  id_transacao    valor id_loja
# 0           1     768805383    50.74  magalu
# 1           1      76856563  2000.90  magalu
# 2           1     767573759    15.70  subway

# %% [markdown]
# ### Query 4
#
# ```sql
# SELECT *
# FROM transacoes
# WHERE valor BETWEEN 60 AND 1000;
# ```

# %%
query_4
# Out:
#    id_cliente  id_transacao  valor     id_loja
# 0           3     818770008  110.0  postoshell

# %% [markdown]
# ## LIKE + WILDCARDS
#
# ### Query 5
#
# ```sql
# SELECT *
# FROM transacoes
# WHERE id_loja LIKE 'mag%'
# ```

# %%
query_5
# Out:
#    id_cliente  id_transacao    valor id_loja
# 0           1     768805383    50.74  magalu
# 1           1      76856563  2000.90  magalu

# %% [markdown]
# ### Query 6
#
# ```sql
# SELECT *
# FROM transacoes
# WHERE id_loja LIKE '%sh%'
# ```

# %%
 query_6
# Out:
#    id_cliente  id_transacao   valor     id_loja
# 0           3     818770008   110.0  postoshell
# 1           3    8154567758  1100.0      shopee

# %% [markdown]
# ## Conditional Selection
#
# ### Query 7
#
# ```sql
# SELECT id_cliente, id_loja, valor,
# CASE
#     WHEN valor > 1000 THEN 'Compra com alto valor'
#     WHEN valor < 1000 THEN 'Compra com baixo valor'
# END
# AS classValor,
# CASE
#     WHEN id_loja IN ('giraffas', 'subway') THEN 'alimentacao'
#     WHEN id_loja IN ('magalu', 'extra') THEN 'variedade'
#     WHEN id_loja IN ('postoshell', 'seveneleven') THEN '24horas'
#     ELSE 'outros'
# END
# AS tipo_compra
# FROM transacoes;
# ```

# %%
query_7
# Out:
#    id_cliente      id_loja    valor              classValor  tipo_compra
# 0           1       magalu    50.74  Compra com baixo valor    variedade
# 1           2     giraffas    30.90  Compra com baixo valor  alimentacao
# 2           3   postoshell   110.00  Compra com baixo valor      24horas
# 3           1       magalu  2000.90   Compra com alto valor    variedade
# 4           1       subway    15.70  Compra com baixo valor  alimentacao
# 5           3  seveneleven     2.99  Compra com baixo valor      24horas
# 6           4        extra    50.74  Compra com baixo valor    variedade
# 7           5       subway    10.00  Compra com baixo valor  alimentacao
# 8           3       shopee  1100.00   Compra com alto valor       outros
